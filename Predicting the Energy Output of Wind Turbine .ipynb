# %%
import boto3,os, sagemaker
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                                
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.session import s3_input,Session
import os
from sagemaker.predictor import csv_serializer

# %%
s3 = boto3.resource('s3')
bucket_name = "winddata"
data_key = "T1.csv"
data_location = "s3://{}/{}".format(bucket_name,data_key)

role = get_execution_role()

my_region = boto3.session.Session().region_name

model_data=pd.read_csv(data_location)

# %%
model_data
# Out:
#               Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0      01 01 2018 00:00           380.047791          5.311336
# 1      01 01 2018 00:10           453.769196          5.672167
# 2      01 01 2018 00:20           306.376587          5.216037
# 3      01 01 2018 00:30           419.645905          5.659674
# 4      01 01 2018 00:40           380.650696          5.577941
# ...                 ...                  ...               ...
# 50525  31 12 2018 23:10          2963.980957         11.404030
# 50526  31 12 2018 23:20          1684.353027          7.332648
# 50527  31 12 2018 23:30          2201.106934          8.435358
# 50528  31 12 2018 23:40          2515.694092          9.421366
# 50529  31 12 2018 23:50          2820.466064          9.979332
#
#        Theoretical_Power_Curve (KWh)  Wind Direction (°)
# 0                         416.328908          259.994904
# 1                         519.917511          268.641113
# 2                         390.900016          272.564789
# 3                         516.127569          271.258087
# 4                         491.702972          265.674286
# ...                              ...                 ...
# 50525                    3397.190793           80.502724
# 50526                    1173.055771           84.062599
# 50527                    1788.284755           84.742500
# 50528                    2418.382503           84.297913
# 50529                    2779.184096           82.274620
#
# [50530 rows x 5 columns]

# %%
model_data["Date/Time"] = pd.to_datetime(model_data["Date/Time"])

# %%
model_data.set_index("Date/Time",inplace=True)

# %%
train_data , test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data))])
print(train_data.shape, test_data.shape)
# Out:
# (35371, 4) (15159, 4)

# %%
print(role)
print(my_region)
# Out:
# arn:aws:iam::748050252648:role/service-role/AmazonSageMaker-ExecutionRole-20201012T200352
# us-east-1

# %%
prefix = 'sagemaker/DEMO-xgboost-dm'
output_path='s3://{}/{}/output'.format(bucket_name,prefix)
print(output_path)
# Out:
# s3://winddata/sagemaker/DEMO-xgboost-dm/output

# %%
model_data
# Out:
#                      LV ActivePower (kW)  Wind Speed (m/s)  \
# Date/Time
# 2018-01-01 00:00:00           380.047791          5.311336
# 2018-01-01 00:10:00           453.769196          5.672167
# 2018-01-01 00:20:00           306.376587          5.216037
# 2018-01-01 00:30:00           419.645905          5.659674
# 2018-01-01 00:40:00           380.650696          5.577941
# ...                                  ...               ...
# 2018-12-31 23:10:00          2963.980957         11.404030
# 2018-12-31 23:20:00          1684.353027          7.332648
# 2018-12-31 23:30:00          2201.106934          8.435358
# 2018-12-31 23:40:00          2515.694092          9.421366
# 2018-12-31 23:50:00          2820.466064          9.979332
#
#                      Theoretical_Power_Curve (KWh)  Wind Direction (°)
# Date/Time
# 2018-01-01 00:00:00                     416.328908          259.994904
# 2018-01-01 00:10:00                     519.917511          268.641113
# 2018-01-01 00:20:00                     390.900016          272.564789
# 2018-01-01 00:30:00                     516.127569          271.258087
# 2018-01-01 00:40:00                     491.702972          265.674286
# ...                                            ...                 ...
# 2018-12-31 23:10:00                    3397.190793           80.502724
# 2018-12-31 23:20:00                    1173.055771           84.062599
# 2018-12-31 23:30:00                    1788.284755           84.742500
# 2018-12-31 23:40:00                    2418.382503           84.297913
# 2018-12-31 23:50:00                    2779.184096           82.274620
#
# [50530 rows x 4 columns]

# %%
pd.concat([train_data['LV ActivePower (kW)'], train_data.drop(['LV ActivePower (kW)'], axis=1)], axis=1).to_csv('Train.csv', index=False, header=False)

# %%
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix,'Train/Train.csv')).upload_file('Train.csv')
s3_input_Train = sagemaker.s3_input(s3_data="s3://{}/{}/Train/Train".format(bucket_name,prefix),content_type="csv")
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
pd.concat([train_data['LV ActivePower (kW)'], train_data.drop(['LV ActivePower (kW)'], axis=1)], axis=1).to_csv('Test.csv', index=False, header=False)
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix,'Test/Test.csv')).upload_file('Test.csv')
s3_input_Test = sagemaker.s3_input(s3_data="s3://{}/{}/Test/Test".format(bucket_name,prefix),content_type="csv")
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
model_data
# Out:
#                      LV ActivePower (kW)  Wind Speed (m/s)  \
# Date/Time
# 2018-01-01 00:00:00           380.047791          5.311336
# 2018-01-01 00:10:00           453.769196          5.672167
# 2018-01-01 00:20:00           306.376587          5.216037
# 2018-01-01 00:30:00           419.645905          5.659674
# 2018-01-01 00:40:00           380.650696          5.577941
# ...                                  ...               ...
# 2018-12-31 23:10:00          2963.980957         11.404030
# 2018-12-31 23:20:00          1684.353027          7.332648
# 2018-12-31 23:30:00          2201.106934          8.435358
# 2018-12-31 23:40:00          2515.694092          9.421366
# 2018-12-31 23:50:00          2820.466064          9.979332
#
#                      Theoretical_Power_Curve (KWh)  Wind Direction (°)
# Date/Time
# 2018-01-01 00:00:00                     416.328908          259.994904
# 2018-01-01 00:10:00                     519.917511          268.641113
# 2018-01-01 00:20:00                     390.900016          272.564789
# 2018-01-01 00:30:00                     516.127569          271.258087
# 2018-01-01 00:40:00                     491.702972          265.674286
# ...                                            ...                 ...
# 2018-12-31 23:10:00                    3397.190793           80.502724
# 2018-12-31 23:20:00                    1173.055771           84.062599
# 2018-12-31 23:30:00                    1788.284755           84.742500
# 2018-12-31 23:40:00                    2418.382503           84.297913
# 2018-12-31 23:50:00                    2779.184096           82.274620
#
# [50530 rows x 4 columns]

# %%
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'}

# %%
s3_input_Train

# %%
sess = sagemaker.Session()
xgb = sagemaker.estimator.Estimator(containers[my_region],
                                    role, train_instance_count=1,
                                    train_instance_type='ml.m5.large',
                                    output_path=output_path,
                                    sagemaker_session=sess)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %%
xgb.set_hyperparameters(objective='reg:linear',num_round=100)

# %%
xgb.fit({'train':s3_input_Train})
# Out:
# 2020-10-12 14:48:49 Starting - Starting the training job...
# 2020-10-12 14:48:53 Starting - Launching requested ML instances......
# 2020-10-12 14:50:15 Starting - Preparing the instances for training......
# 2020-10-12 14:51:08 Downloading - Downloading input data...
# 2020-10-12 14:51:45 Training - Downloading the training image..Arguments: train
# [2020-10-12:14:52:00:INFO] Running standalone xgboost training.
# [2020-10-12:14:52:00:INFO] Path /opt/ml/input/data/validation does not exist!
# [2020-10-12:14:52:00:INFO] File size need to be processed in the node: 2.14mb. Available memory size in the node: 167.29mb
# [2020-10-12:14:52:00:INFO] Determined delimiter of CSV input is ','
# [14:52:00] S3DistributionType set as FullyReplicated
# [14:52:00] 35371x3 matrix with 106113 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 116 extra nodes, 0 pruned nodes, max_depth=6
# [0]#011train-rmse:1325.83
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 114 extra nodes, 0 pruned nodes, max_depth=6
# [1]#011train-rmse:966.903
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 118 extra nodes, 0 pruned nodes, max_depth=6
# [2]#011train-rmse:728.335
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 122 extra nodes, 0 pruned nodes, max_depth=6
# [3]#011train-rmse:574.98
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 124 extra nodes, 0 pruned nodes, max_depth=6
# [4]#011train-rmse:481.145
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 112 extra nodes, 0 pruned nodes, max_depth=6
# [5]#011train-rmse:426.504
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 104 extra nodes, 0 pruned nodes, max_depth=6
# [6]#011train-rmse:396.668
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [7]#011train-rmse:380.369
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [8]#011train-rmse:371.39
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 100 extra nodes, 0 pruned nodes, max_depth=6
# [9]#011train-rmse:366.141
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 110 extra nodes, 0 pruned nodes, max_depth=6
# [10]#011train-rmse:361.677
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [11]#011train-rmse:359.68
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [12]#011train-rmse:358.52
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [13]#011train-rmse:357.247
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 52 extra nodes, 0 pruned nodes, max_depth=6
# [14]#011train-rmse:356.257
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [15]#011train-rmse:354.112
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [16]#011train-rmse:352.694
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [17]#011train-rmse:351.393
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [18]#011train-rmse:350.545
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [19]#011train-rmse:349.741
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [20]#011train-rmse:349.29
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [21]#011train-rmse:348.41
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 92 extra nodes, 0 pruned nodes, max_depth=6
# [22]#011train-rmse:346.906
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [23]#011train-rmse:345.681
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [24]#011train-rmse:344.432
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [25]#011train-rmse:344.012
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [26]#011train-rmse:342.792
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [27]#011train-rmse:342.096
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [28]#011train-rmse:341.453
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [29]#011train-rmse:340.758
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [30]#011train-rmse:339.627
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [31]#011train-rmse:339.063
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [32]#011train-rmse:338.393
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [33]#011train-rmse:338.131
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 58 extra nodes, 0 pruned nodes, max_depth=6
# [34]#011train-rmse:337.112
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [35]#011train-rmse:335.83
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [36]#011train-rmse:335.025
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [37]#011train-rmse:334.052
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [38]#011train-rmse:333.345
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [39]#011train-rmse:332.466
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 90 extra nodes, 0 pruned nodes, max_depth=6
# [40]#011train-rmse:331.62
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [41]#011train-rmse:330.658
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [42]#011train-rmse:330.024
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [43]#011train-rmse:329.725
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [44]#011train-rmse:329.461
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [45]#011train-rmse:328.903
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [46]#011train-rmse:328.13
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [47]#011train-rmse:327.049
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [48]#011train-rmse:326.185
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [49]#011train-rmse:325.496
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [50]#011train-rmse:325.091
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [51]#011train-rmse:323.781
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [52]#011train-rmse:322.927
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [53]#011train-rmse:321.849
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [54]#011train-rmse:320.887
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [55]#011train-rmse:319.945
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [56]#011train-rmse:319.294
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 82 extra nodes, 0 pruned nodes, max_depth=6
# [57]#011train-rmse:318.35
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 76 extra nodes, 0 pruned nodes, max_depth=6
# [58]#011train-rmse:317.409
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [59]#011train-rmse:316.218
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [60]#011train-rmse:315.185
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [61]#011train-rmse:314.334
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [62]#011train-rmse:314.061
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [63]#011train-rmse:313.311
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [64]#011train-rmse:313.168
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [65]#011train-rmse:312.618
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [66]#011train-rmse:312.566
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [67]#011train-rmse:312.497
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [68]#011train-rmse:312.204
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [69]#011train-rmse:311.524
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 108 extra nodes, 0 pruned nodes, max_depth=6
# [70]#011train-rmse:310.859
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [71]#011train-rmse:309.953
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [72]#011train-rmse:309.407
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [73]#011train-rmse:308.473
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 86 extra nodes, 0 pruned nodes, max_depth=6
# [74]#011train-rmse:307.451
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 62 extra nodes, 0 pruned nodes, max_depth=6
# [75]#011train-rmse:307.024
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 50 extra nodes, 0 pruned nodes, max_depth=6
# [76]#011train-rmse:306.839
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 54 extra nodes, 0 pruned nodes, max_depth=6
# [77]#011train-rmse:306.351
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 80 extra nodes, 0 pruned nodes, max_depth=6
# [78]#011train-rmse:305.918
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 88 extra nodes, 0 pruned nodes, max_depth=6
# [79]#011train-rmse:304.937
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [80]#011train-rmse:304.049
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [81]#011train-rmse:303.468
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [82]#011train-rmse:302.967
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 60 extra nodes, 0 pruned nodes, max_depth=6
# [83]#011train-rmse:302.502
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 74 extra nodes, 0 pruned nodes, max_depth=6
# [84]#011train-rmse:301.215
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [85]#011train-rmse:300.708
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [86]#011train-rmse:300.4
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [87]#011train-rmse:300.2
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 96 extra nodes, 0 pruned nodes, max_depth=6
# [88]#011train-rmse:299.621
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 56 extra nodes, 0 pruned nodes, max_depth=6
# [89]#011train-rmse:299.133
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 78 extra nodes, 0 pruned nodes, max_depth=6
# [90]#011train-rmse:298.667
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 66 extra nodes, 0 pruned nodes, max_depth=6
# [91]#011train-rmse:297.775
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 72 extra nodes, 0 pruned nodes, max_depth=6
# [92]#011train-rmse:296.761
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 64 extra nodes, 0 pruned nodes, max_depth=6
# [93]#011train-rmse:296.503
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 98 extra nodes, 0 pruned nodes, max_depth=6
# [94]#011train-rmse:296.234
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 70 extra nodes, 0 pruned nodes, max_depth=6
# [95]#011train-rmse:295.825
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [96]#011train-rmse:295.654
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 84 extra nodes, 0 pruned nodes, max_depth=6
# [97]#011train-rmse:295.437
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 94 extra nodes, 0 pruned nodes, max_depth=6
# [98]#011train-rmse:295.055
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 68 extra nodes, 0 pruned nodes, max_depth=6
# [99]#011train-rmse:294.92
#
# 2020-10-12 14:52:20 Uploading - Uploading generated training model
# 2020-10-12 14:52:27 Completed - Training job completed
# Training seconds: 79
# Billable seconds: 79

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1,instance_type='ml.m5.large')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -------------!

# %%
test_data_array = test_data.drop(['LV ActivePower (kW)'], axis=1).values #load the data into an array
xgb_predictor.content_type = 'text/csv' # set the data type for an inference
xgb_predictor.serializer = csv_serializer # set the serializer type
predictions = xgb_predictor.predict(test_data_array).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[1:], sep=',') # and turn the prediction into an array
print(predictions_array.shape)
# Out:
# (15159,)

# %%
xgb_predictor.endpoint
# Out:
# 'xgboost-2020-10-12-14-48-48-978'
